# %% [markdown]
# ### I am creating a pie chart using built-in mtcars data set in R

# %%
# First create a bar chart of a variable gear

library(ggplot2)
BarPlt <- ggplot(mtcars, aes(x =1, y = sort(mtcars$gear), fill = sort(mtcars$gear))) + geom_bar(stat = 'identity')

# %%
print(BarPlt)
# Out:
# plot without title

# %%
# here we change the value of y into angle using coord_polar

BarPlt <- BarPlt + coord_polar(theta = "y")
print(BarPlt)
# Out:
# plot without title

# %%
# changing all value in axis line to blank
BarPlt <- BarPlt + theme(axis.line = element_blank(), axis.text.x = element_blank(), axis.text.y  = element_blank(), axis.ticks = element_blank(), axis.title.y = element_blank())

# %%
print(BarPlt)
# Out:
# plot without title

# %%
 
BarPlt <- BarPlt + theme(axis.line = element_blank(), axis.text.x = element_blank(), axis.text.y  = element_blank(), axis.ticks = element_blank(), axis.title.y = element_blank(), panel.background = element_blank())

# %%
print(BarPlt)
# Out:
# plot without title

# %%
BarPlt <- BarPlt + coord_polar(theta = "y")
BarPlt <- BarPlt + theme(axis.line = element_blank(), axis.text.x = element_blank(), axis.text.y  = element_blank(), axis.ticks = element_blank(), axis.title.y = element_blank(), panel.background = element_blank())+ labs(y = 'Gear')+ ggtitle("Pie Chart of Gear")

# %%
print(BarPlt)
# Out:
# plot without title
